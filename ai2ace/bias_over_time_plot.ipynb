# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

def compute_global_mean(wx_data, truth, mask):
    bias = wx_data.mean(dim='time') - truth.mean(dim='time')
    bias = bias*mask
    weights = np.cos(np.deg2rad(bias.latitude))
    weights.name = "weights"
    weighted = bias.weighted(weights)
    bias = weighted.mean(dim=('latitude', 'longitude')).values
    return bias
